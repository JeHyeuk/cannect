# %%
# !git clone 'https://github.com/labwons/pylabwons-archive.git'
# %cd pylabwons-archive

# !pip install -e .
# %cd ..
# Out:
# Cloning into 'pylabwons-archive'...
# remote: Enumerating objects: 309, done.
# remote: Counting objects: 100% (309/309), done.
# remote: Compressing objects: 100% (229/229), done.
# remote: Total 309 (delta 119), reused 230 (delta 62), pack-reused 0 (from 0)
# Receiving objects: 100% (309/309), 7.81 MiB | 21.38 MiB/s, done.
# Resolving deltas: 100% (119/119), done.
# /content/pylabwons-archive
# Obtaining file:///content/pylabwons-archive
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from pylabwons_stub==0.1.0) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from pylabwons_stub==0.1.0) (2.2.2)
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (from pylabwons_stub==0.1.0) (5.24.1)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.12/dist-packages (from pylabwons_stub==0.1.0) (18.1.0)
# Collecting pylabwons (from pylabwons_stub==0.1.0)
#   Downloading pylabwons-1.1.7-py3-none-any.whl.metadata (439 bytes)
# Collecting pykrx (from pylabwons_stub==0.1.0)
#   Downloading pykrx-1.2.4-py3-none-any.whl.metadata (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.0/64.0 kB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from pylabwons_stub==0.1.0) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from pylabwons_stub==0.1.0) (4.67.3)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.12/dist-packages (from pylabwons_stub==0.1.0) (2.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->pylabwons_stub==0.1.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->pylabwons_stub==0.1.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->pylabwons_stub==0.1.0) (2025.3)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly->pylabwons_stub==0.1.0) (9.1.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from plotly->pylabwons_stub==0.1.0) (26.0)
# Collecting numpy (from pylabwons_stub==0.1.0)
#   Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 4.8 MB/s eta 0:00:00
# Collecting deprecated>=1.2.14 (from pykrx->pylabwons_stub==0.1.0)
#   Downloading deprecated-1.3.1-py2.py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: multipledispatch>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from pykrx->pylabwons_stub==0.1.0) (1.0.0)
# Requirement already satisfied: matplotlib>=3.8.0 in /usr/local/lib/python3.12/dist-packages (from pykrx->pylabwons_stub==0.1.0) (3.10.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->pylabwons_stub==0.1.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->pylabwons_stub==0.1.0) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->pylabwons_stub==0.1.0) (2026.2.25)
# Requirement already satisfied: lxml in /usr/local/lib/python3.12/dist-packages (from pylabwons->pylabwons_stub==0.1.0) (6.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from pylabwons->pylabwons_stub==0.1.0) (1.16.3)
# Collecting ta (from pylabwons->pylabwons_stub==0.1.0)
#   Downloading ta-0.11.0.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: wrapt<3,>=1.10 in /usr/local/lib/python3.12/dist-packages (from deprecated>=1.2.14->pykrx->pylabwons_stub==0.1.0) (2.1.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8.0->pykrx->pylabwons_stub==0.1.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8.0->pykrx->pylabwons_stub==0.1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8.0->pykrx->pylabwons_stub==0.1.0) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8.0->pykrx->pylabwons_stub==0.1.0) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8.0->pykrx->pylabwons_stub==0.1.0) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8.0->pykrx->pylabwons_stub==0.1.0) (3.3.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->pylabwons_stub==0.1.0) (1.17.0)
# Downloading pykrx-1.2.4-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 51.2 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 83.3 MB/s eta 0:00:00
# Downloading pylabwons-1.1.7-py3-none-any.whl (21 kB)
# Downloading deprecated-1.3.1-py2.py3-none-any.whl (11 kB)
# Building wheels for collected packages: pylabwons_stub, ta
#   Building editable for pylabwons_stub (pyproject.toml) ... done
#   Created wheel for pylabwons_stub: filename=pylabwons_stub-0.1.0-0.editable-py3-none-any.whl size=2197 sha256=eb8450434f9400be8a30acb87ea3099085307b58c7e2c7a9ba0b8c66333c2ad3
#   Stored in directory: /tmp/pip-ephem-wheel-cache-tvgei_0z/wheels/47/c0/96/9de91a06df5307e8b45c53f9fe34e6c8125efc824dad5f1ca1
#   Building wheel for ta (setup.py) ... done
#   Created wheel for ta: filename=ta-0.11.0-py3-none-any.whl size=29412 sha256=ccbd699ab83d106184b920001dd337acd04af5103372961a8ccaff01e63f5b6a
#   Stored in directory: /root/.cache/pip/wheels/5c/a1/5f/c6b85a7d9452057be4ce68a8e45d77ba34234a6d46581777c6
# Successfully built pylabwons_stub ta
# Installing collected packages: numpy, deprecated, ta, pykrx, pylabwons, pylabwons_stub
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# xarray-einstats 0.10.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# pytensor 2.38.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# rasterio 1.5.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# shap 0.50.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# tobler 0.13.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# Successfully installed deprecated-1.3.1 numpy-1.26.4 pykrx-1.2.4 pylabwons-1.1.7 pylabwons_stub-0.1.0 ta-0.11.0
# /content

# %% [markdown]
# # Environment

# %%
from google.colab import userdata
import pylabwons as lw
import pylabwons_stub as lws
import os


os.environ['GIT_REPO_NAME'] = GIT_REPO = 'pylabwons-archive'
for key in [
    'GIT_TOKEN_PYLABWONS_ARCHIVE',
    'GIT_USER',
    'GIT_EMAIL',
    'KRX_ID',
    'KRX_PW'
]:
    os.environ[key] = userdata.get(key)
    if key.startswith('GIT_TOKEN') and key.endswith(GIT_REPO.upper().replace('-', '_')):
        os.environ['GIT_TOKEN'] = userdata.get(key)
e = lw.DataDict(os.environ)

# %% [markdown]
# # Build

# %%
lw.login_krx(e.KRX_ID, e.KRX_PW)

baseline = lws.Baseline(logger=lw.Logger())
baseline.build()
baseline.dates
# Out:
# 2026-03-09 13:08:57 [BUILD BASELINE] @20260306
# 0it [00:00, ?it/s]
# 2026-03-09 13:08:59 FETCH MARKET NUMBERS OF 20260306
# 2026-03-09 13:28:20 .............................. 1329 STOCKS / RUNTIME: 1161.13s
# /content/pylabwons-archive/src/pylabwons_stub/core/build/baseline.py:137: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self.number[col] = self.number[col].fillna(0).infer_objects(copy=False)
# /content/pylabwons-archive/src/pylabwons_stub/core/build/baseline.py:137: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self.number[col] = self.number[col].fillna(0).infer_objects(copy=False)
# /content/pylabwons-archive/src/pylabwons_stub/core/build/baseline.py:137: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self.number[col] = self.number[col].fillna(0).infer_objects(copy=False)
# 2026-03-09 13:28:20 Unable to cast <fiscalNetProfitGrowth: object -> numeric>, could not convert string to float: '흑자전환'
# 2026-03-09 13:28:20 Unable to cast <fiscalEpsGrowth: object -> numeric>, could not convert string to float: '흑자전환'
# 2026-03-09 13:28:20 Unable to cast <yoyRevenue: object -> numeric>, could not convert string to float: '흑자전환'
# 2026-03-09 13:28:20 Unable to cast <yoyProfit: object -> numeric>, could not convert string to float: '적자지속'
# 2026-03-09 13:28:20 Unable to cast <yoyNetProfit: object -> numeric>, could not convert string to float: '적자지속'
# 2026-03-09 13:28:20 Unable to cast <yoyProfitRate: object -> numeric>, could not convert string to float: '적자전환'
# 2026-03-09 13:28:20 Unable to cast <estimatedNetProfitGrowth: object -> numeric>, could not convert string to float: '적자지속'
# 2026-03-09 13:28:20 Unable to cast <estimatedDebtGrowth: object -> numeric>, could not convert string to float: '적자전환'
# 2026-03-09 13:28:20 Unable to cast <estimatedProfitRateGrowth: object -> numeric>, could not convert string to float: '적자지속'
# 2026-03-09 13:28:20 Unable to cast <estimatedEpsGrowth: object -> numeric>, could not convert string to float: '적자지속'
# 2026-03-09 13:28:20 Unable to cast <yoyProfit: object -> numeric>, could not convert string to float: '적자전환'
# 2026-03-09 13:28:20 Unable to cast <estimatedDebtGrowth: object -> numeric>, could not convert string to float: '적자전환'
# 2026-03-09 13:28:20 Unable to cast <fiscalEpsGrowth: object -> numeric>, could not convert string to float: '적자지속'
# 2026-03-09 13:28:20 Unable to cast <estimatedNetProfitGrowth: object -> numeric>, could not convert string to float: '적자지속'
# 2026-03-09 13:28:20 Unable to cast <yoyRevenue: object -> numeric>, could not convert string to float: '흑자전환'
# 2026-03-09 13:28:20 Unable to cast <fiscalNetProfitGrowth: object -> numeric>, could not convert string to float: '흑자전환'
# 2026-03-09 13:28:20 Unable to cast <estimatedEpsGrowth: object -> numeric>, could not convert string to float: '흑자전환'
# 2026-03-09 13:28:20 Unable to cast <yoyProfitRate: object -> numeric>, could not convert string to float: '적자전환'
# 2026-03-09 13:28:20 Unable to cast <yoyNetProfit: object -> numeric>, could not convert string to float: '적자지속'
# 2026-03-09 13:28:20 Unable to cast <estimatedProfitRateGrowth: object -> numeric>, could not convert string to float: '흑자전환'
# {'baseline': {'date': '20260306'},
#  'aftermarket': {'date': '20260306'},
#  'numbers': {'date': '1970-01-01 00:00:00.020260306'},
#  'wics': {'date': '20260306'}}

# %% [markdown]
# # Commit & Push

# %%
if lws.HOST == 'google_colab':
    import os
    if not os.getcwd().endswith(e.GIT_REPO_NAME):
        # %cd $e.GIT_REPO_NAME

    # !git config --global user.name "$GIT_USER"
    # !git config --global user.email "$GIT_EMAIL"
    # !git remote set-url origin "https://${GIT_USER}:${GIT_TOKEN}@github.com/${GIT_USER}/${GIT_REPO_NAME}.git"
    # !git add .
    # !git commit -m "COMMIT AND PUSH FROM COLAB"
    # !git push origin main
# Out:
# /content/pylabwons-archive
# [main 13ef3ac] COMMIT AND PUSH FROM COLAB
#  4 files changed, 2467 insertions(+), 2467 deletions(-)
#  rewrite data/src/baseline.csv (61%)
#  rewrite data/src/numbers.parquet (88%)
# Enumerating objects: 17, done.
# Counting objects: 100% (17/17), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (8/8), done.
# Writing objects: 100% (9/9), 342.86 KiB | 4.08 MiB/s, done.
# Total 9 (delta 4), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (4/4), completed with 4 local objects.
# To https://github.com/labwons/pylabwons-archive.git
#    292b791..13ef3ac  main -> main
